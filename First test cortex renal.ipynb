# %%
import matplotlib.pyplot as plt
import nibabel as nib
import numpy as np
import vtk

img = nib.load('data_cortex/source/cortex_renal_1_1.nii.gz')
header = img.header
img_data = img.get_data()

print(img_data.shape)
# Out:
# (192, 192, 1)

# %%
import os

list_files = os.listdir('data_cortex/source')

for file in list_files:
    img = nib.load('data_cortex/source/{}'.format(file))
    plt.imshow(img.get_data().reshape((192,192)))
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-79a2314db6f1> in <module>()
#       5 for file in list_files:
#       6     img = nib.load('data_cortex/source/{}'.format(file))
# ----> 7     plt.imshow(img.get_data().reshape((192,192)))
#       8     plt.show()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3083            filternorm=1, filterrad=4.0, imlim=None, resample=None, url=None,
#    3084            hold=None, data=None, **kwargs):
# -> 3085     ax = gca()
#    3086     # Deprecated: allow callers to override the hold state
#    3087     # by passing hold=True|False
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\pyplot.py in gca(**kwargs)
# ...

# %%
import os

list_files = os.listdir('data_cortex/masks')

for file in list_files:
    img = nib.load('data_cortex/masks/{}'.format(file))
    plt.imshow(img.get_data().reshape((192,192)))
    plt.show()
