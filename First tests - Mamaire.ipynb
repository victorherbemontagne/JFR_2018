# %%
import matplotlib.pyplot as plt
import nibabel as nib
import numpy as np
import vtk

img = nib.load('data/sein_1.nii.gz')
header = img.header
img_data = img.get_data()

print(img_data.shape)
# Out:
# (440, 440)

# %%
import pandas as pd

df_labels = pd.read_csv("infos/train_set.csv")

# %%
all_deseases = df_labels['Type de lésion'].value_counts()

# %%
all_deseases
# Out:
# Tissu glandulaire                    62
# Carcinome canalaire infiltrant       53
# Cancer triple négatif                13
# ganglio intra-mammaire               12
# Fibroadénome                         10
# Kyste                                10
# Carcinome lobulaire infiltrant        9
# cytostéatonécrose                     7
# Autre lésion proliférante             7
# Adénose sclérosante                   3
# Carcinome intracanalaire              3
# Galactophorite                        3
# Hyperplasie canalaire sans atypie     2
# Carcinome mucineux                    2
# Cicatrice radiaire                    2
# PASH                                  1
# Papillome                             1
# Name: Type de lésion, dtype: int64

# %%
import os

list_files = os.listdir('data')

for file in list_files:
    img = nib.load('data/{}'.format(file))
    plt.imshow(img_data)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-db8eb012fa8f> in <module>()
#       6     img = nib.load('data/{}'.format(file))
#       7     plt.imshow(img_data)
# ----> 8     plt.show()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     252     """
#     253     global _show
# --> 254     return _show(*args, **kw)
#     255
#     256
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      34     try:
#      35         for figure_manager in Gcf.get_all_fig_managers():
# ---> 36             display(figure_manager.canvas.figure)
#      37     finally:
#      38         show._to_draw = []
#
# ...
